# %%
import pandas as pd
import numpy as np
import random
import matplotlib.pyplot as plt
import statsmodels.api as sm
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import r2_score, mean_absolute_error
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.svm import SVR
from xgboost import XGBRegressor
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split,GridSearchCV,RandomizedSearchCV
from sklearn.ensemble import RandomForestRegressor

# %%
df = pd.read_csv('hdb-price-with-features-2004to2013.csv').iloc[:, 1:]
df.head()
# Out:
#         month    town flat_type block   street_name storey_range  \
# 0  2012-02-01  BISHAN    5 ROOM   289  BISHAN ST 24     07 TO 09
# 1  2011-12-01  BISHAN    4 ROOM   289  BISHAN ST 24     07 TO 09
# 2  2011-12-01  BISHAN    5 ROOM   289  BISHAN ST 24     13 TO 15
# 3  2011-11-01  BISHAN    4 ROOM   289  BISHAN ST 24     04 TO 06
# 4  2011-09-01  BISHAN    5 ROOM   289  BISHAN ST 24     19 TO 21
#
#    floor_area_sqm         flat_model  lease_commence_date  remaining_lease  \
# 0           121.0  Premium Apartment                 1998             85.0
# 1           100.0  Premium Apartment                 1998             86.0
# 2           121.0  Premium Apartment                 1998             86.0
# 3           102.0  Premium Apartment                 1998             86.0
# 4           121.0  Premium Apartment                 1998             86.0
#
#    ...  shortest_dist_mall mall_count_within_1km  mall_list_within_1km  \
# 0  ...            0.824707                     1        ['Junction 8']
# 1  ...            0.824707                     1        ['Junction 8']
# 2  ...            0.824707                     1        ['Junction 8']
# 3  ...            0.824707                     1        ['Junction 8']
# 4  ...            0.824707                     1        ['Junction 8']
#
#    school_shortest_dist school_shortest_dist_name  good_sch_count_within_1km  \
# 0              0.214393      Catholic High School                          1
# 1              0.214393      Catholic High School                          1
# 2              0.214393      Catholic High School                          1
# 3              0.214393      Catholic High School                          1
# 4              0.214393      Catholic High School                          1
#
#    good_sch_list_within_1km good_sch_score distance_to_cbd_km  matured
# 0  ['Catholic High School']              3           7.635584        1
# 1  ['Catholic High School']              3           7.635584        1
# 2  ['Catholic High School']              3           7.635584        1
# 3  ['Catholic High School']              3           7.635584        1
# 4  ['Catholic High School']              3           7.635584        1
#
# [5 rows x 29 columns]

# %%
cpi = pd.read_csv('monthly cpi.csv')
cpi = cpi.set_index('Data Series')
cpi_data = pd.DataFrame(cpi.columns, columns=['month'])
cpi_data['CPI'] = pd.to_numeric(np.array(cpi.loc['All Items']))
cpi_data = cpi_data.iloc[1: , :]
cpi_data['month'] = pd.to_datetime(cpi_data['month'])

cpi_data.head()
# Out:
#        month      CPI
# 1 2023-01-01  111.397
# 2 2022-12-01  111.186
# 3 2022-11-01  110.959
# 4 2022-10-01  109.893
# 5 2022-09-01  110.339

# %%
cpi_data.dtypes
# Out:
# month    datetime64[ns]
# CPI             float64
# dtype: object

# %%
df['month'] = pd.to_datetime(df['month'])
df = pd.merge(df, cpi_data, how = 'left')
df['adjusted_price'] = (df['resale_price'] / df['CPI']) * 100
df['year'] = pd.DatetimeIndex(df['month']).year
df.head()
# Out:
#        month    town flat_type block   street_name storey_range  \
# 0 2012-02-01  BISHAN    5 ROOM   289  BISHAN ST 24     07 TO 09
# 1 2011-12-01  BISHAN    4 ROOM   289  BISHAN ST 24     07 TO 09
# 2 2011-12-01  BISHAN    5 ROOM   289  BISHAN ST 24     13 TO 15
# 3 2011-11-01  BISHAN    4 ROOM   289  BISHAN ST 24     04 TO 06
# 4 2011-09-01  BISHAN    5 ROOM   289  BISHAN ST 24     19 TO 21
#
#    floor_area_sqm         flat_model  lease_commence_date  remaining_lease  \
# 0           121.0  Premium Apartment                 1998             85.0
# 1           100.0  Premium Apartment                 1998             86.0
# 2           121.0  Premium Apartment                 1998             86.0
# 3           102.0  Premium Apartment                 1998             86.0
# 4           121.0  Premium Apartment                 1998             86.0
#
#    ...  school_shortest_dist school_shortest_dist_name  \
# 0  ...              0.214393      Catholic High School
# 1  ...              0.214393      Catholic High School
# 2  ...              0.214393      Catholic High School
# 3  ...              0.214393      Catholic High School
# 4  ...              0.214393      Catholic High School
#
#    good_sch_count_within_1km  good_sch_list_within_1km good_sch_score  \
# 0                          1  ['Catholic High School']              3
# 1                          1  ['Catholic High School']              3
# 2                          1  ['Catholic High School']              3
# 3                          1  ['Catholic High School']              3
# 4                          1  ['Catholic High School']              3
#
#    distance_to_cbd_km  matured     CPI adjusted_price  year
# 0            7.635584        1  94.491  756685.821930  2012
# 1            7.635584        1  93.877  637003.738935  2011
# 2            7.635584        1  93.877  754178.339742  2011
# 3            7.635584        1  93.842  610600.797084  2011
# 4            7.635584        1  92.941  753165.987024  2011
#
# [5 rows x 32 columns]

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date',
#        'remaining_lease', 'resale_price', 'address', 'latitude', 'longitude',
#        'shortest_dist_mrt_name', 'shortest_dist_mrt', 'mrt_count_within_1km',
#        'mrt_list_within_1km', 'shortest_dist_mall_name', 'shortest_dist_mall',
#        'mall_count_within_1km', 'mall_list_within_1km', 'school_shortest_dist',
#        'school_shortest_dist_name', 'good_sch_count_within_1km',
#        'good_sch_list_within_1km', 'good_sch_score', 'distance_to_cbd_km',
#        'matured', 'CPI', 'adjusted_price', 'year'],
#       dtype='object')

# %%
data = df.drop(['month','block', 'street_name', 'lease_commence_date',
                'resale_price','address', 'latitude', 'longitude',
                'shortest_dist_mrt_name', 'mrt_list_within_1km',
                'shortest_dist_mall_name','mall_list_within_1km',
                'school_shortest_dist_name', 'good_sch_list_within_1km', 'CPI'],
               axis = 1)
data.head()
# Out:
#      town flat_type storey_range  floor_area_sqm         flat_model  \
# 0  BISHAN    5 ROOM     07 TO 09           121.0  Premium Apartment
# 1  BISHAN    4 ROOM     07 TO 09           100.0  Premium Apartment
# 2  BISHAN    5 ROOM     13 TO 15           121.0  Premium Apartment
# 3  BISHAN    4 ROOM     04 TO 06           102.0  Premium Apartment
# 4  BISHAN    5 ROOM     19 TO 21           121.0  Premium Apartment
#
#    remaining_lease  shortest_dist_mrt  mrt_count_within_1km  \
# 0             85.0           0.754215                     1
# 1             86.0           0.754215                     1
# 2             86.0           0.754215                     1
# 3             86.0           0.754215                     1
# 4             86.0           0.754215                     1
#
#    shortest_dist_mall  mall_count_within_1km  school_shortest_dist  \
# 0            0.824707                      1              0.214393
# 1            0.824707                      1              0.214393
# 2            0.824707                      1              0.214393
# 3            0.824707                      1              0.214393
# 4            0.824707                      1              0.214393
#
#    good_sch_count_within_1km  good_sch_score  distance_to_cbd_km  matured  \
# 0                          1               3            7.635584        1
# 1                          1               3            7.635584        1
# 2                          1               3            7.635584        1
# 3                          1               3            7.635584        1
# 4                          1               3            7.635584        1
#
#    adjusted_price  year
# 0   756685.821930  2012
# 1   637003.738935  2011
# 2   754178.339742  2011
# 3   610600.797084  2011
# 4   753165.987024  2011

# %%
# label encoding for Storey Range
le = LabelEncoder()
data = data.sort_values(by='storey_range')
data['storey_range'] = le.fit_transform(data['storey_range'])


# remove flat_types with less than 1000 instances
flat_types_counts = data['flat_type'].value_counts()
data = data[~data['flat_type'].isin(flat_types_counts[flat_types_counts < 1000].index)]

# label encoding for Storey Range and Flat Type
data = data.sort_values(by='flat_type')
data['flat_type'] = le.fit_transform(data['flat_type'])

# %%
data['flat_model'].value_counts()
# Out:
# Improved               62828
# Model A                62204
# New Generation         41364
# Premium Apartment      16001
# Simplified             12788
# Standard               10560
# Apartment               9397
# Maisonette              6175
# Model A2                4797
# Adjoined flat            498
# Model A-Maisonette       426
# Terrace                  212
# Improved-Maisonette       31
# Premium Maisonette        30
# 2-room                    11
# Name: flat_model, dtype: int64

# %%
# Re-categorize flat models into broader categories
replace_values = {'Model A-Maisonette':'Maisonette', 'Improved-Maisonette':'Maisonette',
                 'Premium Maisonette':'Maisonette',}
data = data.replace({'flat_model': replace_values})

# remove flat models with less than 1000 instances
flat_model_counts = data['flat_model'].value_counts()
data = data[~data['flat_model'].isin(flat_model_counts[flat_model_counts < 1000].index)]

# %%
data = pd.get_dummies(data, columns = ['town','flat_model'],drop_first = True)
data.sort_index(inplace = True)

# %% [markdown]
# #### Check for Multicolinearity and VIF

# %%
import seaborn as sns
fig = plt.figure(figsize=(10,10))
ax = sns.heatmap(data.select_dtypes(include=['int32','int64','float64']).corr(), annot = True, fmt='.2g', 
    vmin=-1, vmax=1, center= 0, cmap= 'coolwarm_r', linecolor='black', linewidth=1, annot_kws={"size": 7})
#ax.set_ylim(0 ,5)
plt.xticks(rotation=45, ha='right')
plt.title('Correlation Heatmap')
fig.show()
# Out:
# C:\Users\tammy\AppData\Local\Temp\ipykernel_4408\2484217916.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# Multicollinearity
# Import library for VIF
from statsmodels.stats.outliers_influence import variance_inflation_factor

def calc_vif(X):
    # Calculating VIF
    vif = pd.DataFrame()
    vif["variables"] = X.columns
    vif["VIF"] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif['tolerance'] = 1/vif.VIF
    vif['meanVIF'] = vif.VIF.mean()

    return(vif)

calc_vif(data.drop('adjusted_price',axis=1).select_dtypes(include=['int32','int64','float64']))
# Out:
#                     variables         VIF  tolerance    meanVIF
# 0                   flat_type   68.254745   0.014651  47.324459
# 1                storey_range    2.599521   0.384686  47.324459
# 2              floor_area_sqm  180.967483   0.005526  47.324459
# 3             remaining_lease  132.538896   0.007545  47.324459
# 4           shortest_dist_mrt    7.427009   0.134644  47.324459
# 5        mrt_count_within_1km    5.187240   0.192781  47.324459
# 6          shortest_dist_mall    7.930638   0.126093  47.324459
# 7       mall_count_within_1km    4.342560   0.230279  47.324459
# 8        school_shortest_dist    4.148283   0.241064  47.324459
# 9   good_sch_count_within_1km   12.872419   0.077685  47.324459
# 10             good_sch_score   12.546521   0.079703  47.324459
# 11         distance_to_cbd_km   23.410691   0.042716  47.324459
# 12                    matured    4.414194   0.226542  47.324459
# 13                       year  195.902226   0.005105  47.324459

# %%
calc_vif(data.drop(['adjusted_price','mrt_count_within_1km','mall_count_within_1km','matured','good_sch_count_within_1km','flat_type','year'],axis=1).select_dtypes(include=['int32','int64','float64']))
# Out:
#               variables        VIF  tolerance   meanVIF
# 0          storey_range   2.568087   0.389395  11.70252
# 1        floor_area_sqm  22.074042   0.045302  11.70252
# 2       remaining_lease  42.160714   0.023719  11.70252
# 3     shortest_dist_mrt   3.767161   0.265452  11.70252
# 4    shortest_dist_mall   3.934648   0.254152  11.70252
# 5  school_shortest_dist   3.657728   0.273394  11.70252
# 6        good_sch_score   1.672275   0.597988  11.70252
# 7    distance_to_cbd_km  13.785509   0.072540  11.70252

# %% [markdown]
# #### Performance Measure

# %%
def model_performance(model):

    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)

    r2 = r2_score(y_test, y_pred)
    mae = mean_absolute_error(y_test, y_pred)

    print('R^2 score =', r2)
    print('Test loss (MAE):', mae)
    
    
    return(r2, mae)

# %% [markdown]
# #### Model Building

# %% [markdown]
# #### Linear Regression

# %%
lr_df = data.drop(['mrt_count_within_1km','mall_count_within_1km','matured','good_sch_count_within_1km','flat_type','year'], axis=1)

# %%
X = lr_df.drop(['adjusted_price'], axis = 1)
y = np.log(lr_df['adjusted_price'])

# %%
# Divide data into training set and test set
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=100)

# %%
continuous_columns = ['floor_area_sqm', 'remaining_lease','shortest_dist_mrt',
                 'shortest_dist_mall', 'school_shortest_dist', 'distance_to_cbd_km']
    

train_scale_data = X_train[continuous_columns]
train_no_scale_data = X_train.drop(continuous_columns, axis = 1)

scaler = StandardScaler()
scaler.fit(train_scale_data)

scaled_train = scaler.transform(train_scale_data)
scaled_train = pd.DataFrame(scaled_train, index = train_scale_data.index ,columns= continuous_columns)
X_train = pd.concat([scaled_train,train_no_scale_data], axis=1)


test_scale_data = X_test[continuous_columns]
test_no_scale_data = X_test.drop(continuous_columns, axis = 1)

scaled_test = scaler.transform(test_scale_data)
scaled_test = pd.DataFrame(scaled_test, index = test_scale_data.index ,columns= continuous_columns)
X_test = pd.concat([scaled_test,test_no_scale_data], axis=1)

# %%
lr = LinearRegression()
lin_reg_r2, lin_reg_mae = model_performance(lr)
# Out:
# R^2 score = 0.6675238972331021
# Test loss (MAE): 0.15888490240356617

# %%
# if remove year
#R^2 score = 0.6675238972331021
#Test loss (MAE): 0.15888490240356617

# if keep year
# R^2 score = 0.8786545461139986
# Test loss (MAE): 0.08883246727760924

# %%
lr_importance = pd.DataFrame(list(zip(X_train.columns, lr.coef_)), columns =['Features', 'Coeff'])
lr_importance.sort_values(by = 'Coeff', ascending = False)
# Out:
#                         Features     Coeff
# 22            town_MARINE PARADE  0.381703
# 13              town_BUKIT TIMAH  0.332904
# 0                 floor_area_sqm  0.273982
# 11              town_BUKIT MERAH  0.170864
# 38  flat_model_Premium Apartment  0.166966
# 36           flat_model_Model A2  0.157888
# 24                  town_PUNGGOL  0.122196
# 14             town_CENTRAL AREA  0.118479
# 9                    town_BISHAN  0.111305
# 25               town_QUEENSTOWN  0.098657
# 16                 town_CLEMENTI  0.095966
# 35            flat_model_Model A  0.086567
# 30                town_TOA PAYOH  0.083392
# 39         flat_model_Simplified  0.078842
# 21          town_KALLANG/WHAMPOA  0.078192
# 17                  town_GEYLANG  0.053194
# 33           flat_model_Improved  0.047825
# 37     flat_model_New Generation  0.045229
# 8                     town_BEDOK  0.031506
# 6                   storey_range  0.028464
# 4           school_shortest_dist  0.000498
# 28                town_SERANGOON -0.002608
# 5             distance_to_cbd_km -0.008230
# 7                 good_sch_score -0.013381
# 1                remaining_lease -0.014075
# 27                 town_SENGKANG -0.025357
# 3             shortest_dist_mall -0.026169
# 29                 town_TAMPINES -0.026654
# 12            town_BUKIT PANJANG -0.026661
# 34         flat_model_Maisonette -0.039619
# 40           flat_model_Standard -0.040525
# 2              shortest_dist_mrt -0.053479
# 18                  town_HOUGANG -0.087507
# 19              town_JURONG EAST -0.089349
# 10              town_BUKIT BATOK -0.095650
# 23                town_PASIR RIS -0.095709
# 26                town_SEMBAWANG -0.138874
# 20              town_JURONG WEST -0.151781
# 32                   town_YISHUN -0.180191
# 15            town_CHOA CHU KANG -0.212516
# 31                town_WOODLANDS -0.218755

# %%
X_constant = sm.add_constant(X)
lr = sm.OLS(y,X_constant).fit()
print(lr.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         adjusted_price   R-squared:                       0.668
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                 1.112e+04
# Date:                Tue, 28 Mar 2023   Prob (F-statistic):               0.00
# Time:                        21:07:42   Log-Likelihood:                 55495.
# No. Observations:              226601   AIC:                        -1.109e+05
# Df Residuals:                  226559   BIC:                        -1.105e+05
# Df Model:                          41
# Covariance Type:            nonrobust
# ================================================================================================
#                                    coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------------------------
# const                           11.9110      0.007   1603.076      0.000      11.896      11.926
# storey_range                     0.0288      0.000    108.239      0.000       0.028       0.029
# floor_area_sqm                   0.0109   2.61e-05    417.242      0.000       0.011       0.011
# remaining_lease                 -0.0015   7.14e-05    -20.319      0.000      -0.002      -0.001
# shortest_dist_mrt               -0.0931      0.001    -83.841      0.000      -0.095      -0.091
# shortest_dist_mall              -0.0508      0.001    -50.466      0.000      -0.053      -0.049
# school_shortest_dist             0.0029      0.002      1.600      0.110      -0.001       0.007
# good_sch_score                  -0.0131      0.001    -21.745      0.000      -0.014      -0.012
# distance_to_cbd_km              -0.0019      0.000     -3.990      0.000      -0.003      -0.001
# town_BEDOK                       0.0302      0.003     12.040      0.000       0.025       0.035
# town_BISHAN                      0.1107      0.004     29.922      0.000       0.103       0.118
# town_BUKIT BATOK                -0.0954      0.003    -28.439      0.000      -0.102      -0.089
# town_BUKIT MERAH                 0.1713      0.004     43.323      0.000       0.164       0.179
# town_BUKIT PANJANG              -0.0273      0.004     -6.630      0.000      -0.035      -0.019
# town_BUKIT TIMAH                 0.3303      0.008     39.429      0.000       0.314       0.347
# town_CENTRAL AREA                0.1187      0.006     18.709      0.000       0.106       0.131
# town_CHOA CHU KANG              -0.2125      0.004    -48.721      0.000      -0.221      -0.204
# town_CLEMENTI                    0.0957      0.003     29.933      0.000       0.089       0.102
# town_GEYLANG                     0.0524      0.004     14.233      0.000       0.045       0.060
# town_HOUGANG                    -0.0870      0.003    -31.260      0.000      -0.092      -0.082
# town_JURONG EAST                -0.0888      0.004    -23.487      0.000      -0.096      -0.081
# town_JURONG WEST                -0.1518      0.005    -33.442      0.000      -0.161      -0.143
# town_KALLANG/WHAMPOA             0.0753      0.004     19.011      0.000       0.068       0.083
# town_MARINE PARADE               0.3781      0.005     71.470      0.000       0.368       0.388
# town_PASIR RIS                  -0.0970      0.004    -24.729      0.000      -0.105      -0.089
# town_PUNGGOL                     0.1210      0.004     27.680      0.000       0.112       0.130
# town_QUEENSTOWN                  0.1000      0.004     28.373      0.000       0.093       0.107
# town_SEMBAWANG                  -0.1373      0.005    -24.984      0.000      -0.148      -0.127
# town_SENGKANG                   -0.0249      0.003     -7.686      0.000      -0.031      -0.019
# town_SERANGOON                  -0.0039      0.003     -1.160      0.246      -0.010       0.003
# town_TAMPINES                   -0.0273      0.003     -8.920      0.000      -0.033      -0.021
# town_TOA PAYOH                   0.0822      0.004     22.824      0.000       0.075       0.089
# town_WOODLANDS                  -0.2174      0.005    -45.051      0.000      -0.227      -0.208
# town_YISHUN                     -0.1784      0.004    -44.942      0.000      -0.186      -0.171
# flat_model_Improved              0.0478      0.002     20.352      0.000       0.043       0.052
# flat_model_Maisonette           -0.0391      0.003    -12.643      0.000      -0.045      -0.033
# flat_model_Model A               0.0857      0.002     35.569      0.000       0.081       0.090
# flat_model_Model A2              0.1546      0.004     41.314      0.000       0.147       0.162
# flat_model_New Generation        0.0450      0.003     16.213      0.000       0.040       0.050
# flat_model_Premium Apartment     0.1667      0.003     60.216      0.000       0.161       0.172
# flat_model_Simplified            0.0791      0.003     25.513      0.000       0.073       0.085
# flat_model_Standard             -0.0440      0.003    -13.550      0.000      -0.050      -0.038
# ==============================================================================
# Omnibus:                     6220.831   Durbin-Watson:                   0.425
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             3307.807
# Skew:                           0.104   Prob(JB):                         0.00
# Kurtosis:                       2.446   Cond. No.                     4.26e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 4.26e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# #### Random Forest

# %%
X = data.drop(['adjusted_price'], axis = 1)
y = np.log(data['adjusted_price'])

# %%
# Divide data into training set and test set
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=100)

# %%
continuous_columns = ['floor_area_sqm', 'remaining_lease','shortest_dist_mrt',
                 'shortest_dist_mall', 'school_shortest_dist', 'distance_to_cbd_km']
    

train_scale_data = X_train[continuous_columns]
train_no_scale_data = X_train.drop(continuous_columns, axis = 1)

scaler = StandardScaler()
scaler.fit(train_scale_data)

scaled_train = scaler.transform(train_scale_data)
scaled_train = pd.DataFrame(scaled_train, index = train_scale_data.index ,columns= continuous_columns)
X_train = pd.concat([scaled_train,train_no_scale_data], axis=1)


test_scale_data = X_test[continuous_columns]
test_no_scale_data = X_test.drop(continuous_columns, axis = 1)

scaled_test = scaler.transform(test_scale_data)
scaled_test = pd.DataFrame(scaled_test, index = test_scale_data.index ,columns= continuous_columns)
X_test = pd.concat([scaled_test,test_no_scale_data], axis=1)

# %%
rf = RandomForestRegressor()
rf_r2, rf_mae = model_performance(rf)
# Out:
# R^2 score = 0.9527841763381694
# Test loss (MAE): 0.0520257610991403

# %%
rf_importance = pd.DataFrame(list(zip(X_train.columns, rf.feature_importances_)), columns =['Features', 'Coeff'])
rf_importance.sort_values(by = 'Coeff', ascending = False)
# Out:
#                         Features     Coeff
# 0                 floor_area_sqm  0.442751
# 13                          year  0.221566
# 6                      flat_type  0.130313
# 5             distance_to_cbd_km  0.086028
# 1                remaining_lease  0.024106
# 2              shortest_dist_mrt  0.023398
# 3             shortest_dist_mall  0.014488
# 7                   storey_range  0.013660
# 12                       matured  0.012121
# 4           school_shortest_dist  0.008978
# 28            town_MARINE PARADE  0.001611
# 11                good_sch_score  0.001607
# 44  flat_model_Premium Apartment  0.001537
# 15                   town_BISHAN  0.001213
# 9          mall_count_within_1km  0.001210
# 39           flat_model_Improved  0.001045
# 41            flat_model_Model A  0.001027
# 8           mrt_count_within_1km  0.000936
# 16              town_BUKIT BATOK  0.000923
# 37                town_WOODLANDS  0.000917
# 10     good_sch_count_within_1km  0.000898
# 20             town_CENTRAL AREA  0.000841
# 31               town_QUEENSTOWN  0.000826
# 22                 town_CLEMENTI  0.000814
# 23                  town_GEYLANG  0.000764
# 34                town_SERANGOON  0.000592
# 17              town_BUKIT MERAH  0.000510
# 14                    town_BEDOK  0.000504
# 25              town_JURONG EAST  0.000466
# 43     flat_model_New Generation  0.000457
# 35                 town_TAMPINES  0.000454
# 46           flat_model_Standard  0.000384
# 19              town_BUKIT TIMAH  0.000368
# 26              town_JURONG WEST  0.000349
# 24                  town_HOUGANG  0.000333
# 36                town_TOA PAYOH  0.000298
# 33                 town_SENGKANG  0.000288
# 27          town_KALLANG/WHAMPOA  0.000236
# 45         flat_model_Simplified  0.000225
# 21            town_CHOA CHU KANG  0.000213
# 18            town_BUKIT PANJANG  0.000209
# 38                   town_YISHUN  0.000170
# 40         flat_model_Maisonette  0.000143
# 42           flat_model_Model A2  0.000090
# 29                town_PASIR RIS  0.000073
# 32                town_SEMBAWANG  0.000045
# 30                  town_PUNGGOL  0.000020

# %% [markdown]
# #### XGBoost

# %%
xgb = XGBRegressor()
xgb_r2, xgb_mae = model_performance(xgb)
# Out:
# R^2 score = 0.9556589769890713
# Test loss (MAE): 0.05154874305563061

# %%
xgb_importance = pd.DataFrame(list(zip(X_train.columns, xgb.feature_importances_)), columns =['Features', 'Coeff'])
xgb_importance.sort_values(by = 'Coeff', ascending = False)
# Out:
#                         Features     Coeff
# 6                      flat_type  0.528939
# 0                 floor_area_sqm  0.091328
# 13                          year  0.072937
# 12                       matured  0.062947
# 37                town_WOODLANDS  0.028283
# 28            town_MARINE PARADE  0.023719
# 15                   town_BISHAN  0.015046
# 5             distance_to_cbd_km  0.013648
# 17              town_BUKIT MERAH  0.012713
# 19              town_BUKIT TIMAH  0.012436
# 22                 town_CLEMENTI  0.012406
# 18            town_BUKIT PANJANG  0.012073
# 25              town_JURONG EAST  0.011121
# 31               town_QUEENSTOWN  0.008890
# 16              town_BUKIT BATOK  0.006355
# 7                   storey_range  0.006224
# 44  flat_model_Premium Apartment  0.006046
# 23                  town_GEYLANG  0.005657
# 34                town_SERANGOON  0.005596
# 2              shortest_dist_mrt  0.004947
# 35                 town_TAMPINES  0.004791
# 33                 town_SENGKANG  0.004090
# 30                  town_PUNGGOL  0.004009
# 1                remaining_lease  0.004003
# 36                town_TOA PAYOH  0.003632
# 24                  town_HOUGANG  0.002980
# 41            flat_model_Model A  0.002765
# 45         flat_model_Simplified  0.002740
# 27          town_KALLANG/WHAMPOA  0.002623
# 11                good_sch_score  0.002590
# 26              town_JURONG WEST  0.002479
# 21            town_CHOA CHU KANG  0.002332
# 14                    town_BEDOK  0.002130
# 32                town_SEMBAWANG  0.002107
# 3             shortest_dist_mall  0.002065
# 39           flat_model_Improved  0.002032
# 46           flat_model_Standard  0.002031
# 38                   town_YISHUN  0.001383
# 43     flat_model_New Generation  0.001365
# 10     good_sch_count_within_1km  0.001304
# 4           school_shortest_dist  0.001049
# 42           flat_model_Model A2  0.001032
# 8           mrt_count_within_1km  0.000956
# 40         flat_model_Maisonette  0.000882
# 9          mall_count_within_1km  0.000727
# 29                town_PASIR RIS  0.000593
# 20             town_CENTRAL AREA  0.000000

# %% [markdown]
# #### Out-of-Bag

# %%
oob_model = RandomForestRegressor(oob_score=True)
oob_r2, oob_mae = model_performance(oob_model)
# Out:
# R^2 score = 0.9526876081777789
# Test loss (MAE): 0.052052454890039644

# %%
oob_importance = pd.DataFrame(list(zip(X_train.columns, oob_model.feature_importances_)), columns =['Features', 'Coeff'])
oob_importance.sort_values(by = 'Coeff', ascending = False)
# Out:
#                         Features     Coeff
# 0                 floor_area_sqm  0.442938
# 13                          year  0.221690
# 6                      flat_type  0.129898
# 5             distance_to_cbd_km  0.086069
# 1                remaining_lease  0.024291
# 2              shortest_dist_mrt  0.023407
# 3             shortest_dist_mall  0.014375
# 7                   storey_range  0.013672
# 12                       matured  0.012296
# 4           school_shortest_dist  0.008826
# 28            town_MARINE PARADE  0.001613
# 44  flat_model_Premium Apartment  0.001560
# 11                good_sch_score  0.001530
# 9          mall_count_within_1km  0.001201
# 15                   town_BISHAN  0.001197
# 39           flat_model_Improved  0.001052
# 41            flat_model_Model A  0.001003
# 16              town_BUKIT BATOK  0.000951
# 8           mrt_count_within_1km  0.000928
# 37                town_WOODLANDS  0.000918
# 10     good_sch_count_within_1km  0.000906
# 31               town_QUEENSTOWN  0.000868
# 20             town_CENTRAL AREA  0.000861
# 22                 town_CLEMENTI  0.000837
# 23                  town_GEYLANG  0.000746
# 34                town_SERANGOON  0.000564
# 17              town_BUKIT MERAH  0.000535
# 14                    town_BEDOK  0.000526
# 25              town_JURONG EAST  0.000461
# 43     flat_model_New Generation  0.000455
# 35                 town_TAMPINES  0.000442
# 19              town_BUKIT TIMAH  0.000365
# 46           flat_model_Standard  0.000357
# 26              town_JURONG WEST  0.000344
# 24                  town_HOUGANG  0.000318
# 36                town_TOA PAYOH  0.000313
# 33                 town_SENGKANG  0.000290
# 27          town_KALLANG/WHAMPOA  0.000235
# 45         flat_model_Simplified  0.000223
# 21            town_CHOA CHU KANG  0.000209
# 18            town_BUKIT PANJANG  0.000196
# 38                   town_YISHUN  0.000167
# 40         flat_model_Maisonette  0.000144
# 42           flat_model_Model A2  0.000088
# 29                town_PASIR RIS  0.000065
# 32                town_SEMBAWANG  0.000047
# 30                  town_PUNGGOL  0.000021
